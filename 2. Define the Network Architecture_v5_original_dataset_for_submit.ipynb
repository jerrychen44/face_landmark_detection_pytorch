# %% [markdown]
# ## Define the Convolutional Neural Network
#
# After we have looked at the data we are working with and, in this case, know the shapes of the images and of the keypoints, we are ready to define a convolutional neural network that can *learn* from this data.
#
# In this notebook and in `models.py`, you will:
# 1. Define a CNN with images as input and keypoints as output
# 2. Construct the transformed FaceKeypointsDataset, just as before
# 3. Train the CNN on the training data, tracking loss
# 4. See how the trained model performs on test data
# 5. If necessary, modify the CNN structure and model hyperparameters, so that it performs *well* **\***
#
# **\*** What does *well* mean?
#
# "Well" means that the model's loss decreases during training **and**, when applied to test image data, the model produces keypoints that closely match the true keypoints of each face. And you'll see examples of this later in the notebook.
#
# ---

# %% [markdown]
# ## CNN Architecture
#
# Recall that CNN's are defined by a few types of layers:
# * Convolutional layers
# * Maxpooling layers
# * Fully-connected layers
#
# You are required to use the above layers and encouraged to add multiple convolutional layers and things like dropout layers that may prevent overfitting. You are also encouraged to look at literature on keypoint detection, such as [this paper](https://arxiv.org/pdf/1710.00977.pdf), to help you determine the structure of your network.
#
#
# ### Define the model in the file `models.py` file
#
#
#
# ---

# %% [markdown]
# ## PyTorch Neural Nets
#
# To define a neural network in PyTorch, you define the layers of a model in the function `__init__` and define the feedforward behavior of a network that employs those initialized layers in the function `forward`, which takes in an input image tensor, `x`. The structure of this Net class is shown below and left for you to fill in.
#
# Note: During training, PyTorch will be able to perform backpropagation by keeping track of the network's feedforward behavior and using autograd to calculate the update to the weights in the network.
#
# #### Define the Layers in ` __init__`
# As a reminder, a conv/pool layer may be defined like this (in `__init__`):
# ```
# # 1 input image channel (for grayscale images), 32 output channels/feature maps, 3x3 square convolution kernel
# self.conv1 = nn.Conv2d(1, 32, 3)
#
# # maxpool that uses a square window of kernel_size=2, stride=2
# self.pool = nn.MaxPool2d(2, 2)
# ```
#
# #### Refer to Layers in `forward`
# Then referred to in the `forward` function like this, in which the conv1 layer has a ReLu activation applied to it before maxpooling is applied:
# ```
# x = self.pool(F.relu(self.conv1(x)))
# ```
#
# Best practice is to place any layers whose weights will change during the training process in `__init__` and refer to them in the `forward` function; any layers or functions that always behave in the same way, such as a pre-defined activation function, should appear *only* in the `forward` function.

# %% [markdown]
# #### Why models.py
#
# You are tasked with defining the network in the `models.py` file so that any models you define can be saved and loaded by name in different notebooks in this project directory. For example, by defining a CNN class called `Net` in `models.py`, you can then create that same architecture in this and other notebooks by simply importing the class and instantiating a model:
# ```
#     from models import Net
#     net = Net()
# ```

# %%
# import the usual resources
import matplotlib.pyplot as plt
import numpy as np
import time
import datetime
# watch for any changes in model.py, if it changes, re-load it automatically
# %load_ext autoreload
# %autoreload 2

# %%
## TODO: Define the Net in models.py

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms, utils,models

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Assume that we are on a CUDA machine, then this should print a CUDA device:
print(device)

# one example conv layer has been provided for you
from models import Net#224

net = Net()
net.to(device)
print(net)
# Out:
# cuda:0
# Net(
#   (conv1): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1))
#   (conv1_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(32, 40, kernel_size=(5, 5), stride=(1, 1))
#   (conv2_bn): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(40, 64, kernel_size=(4, 4), stride=(1, 1))
#   (conv3_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#   (conv4_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4_drop): Dropout(p=0.3)
#   (fc1): Linear(in_features=15488, out_features=5000, bias=True)
#   (fc1_drop): Dropout(p=0.3)
#   (fc2): Linear(in_features=5000, out_features=136, bias=True)
# )

# %% [markdown]
# ## Transform the dataset
#
# To prepare for training, create a transformed dataset of images and keypoints.
#
# ### Define a data transform
#
# In PyTorch, a convolutional neural network expects a torch image of a consistent size as input. For efficient training, and so your model's loss does not blow up during training, it is also suggested that you normalize the input images and keypoints. The necessary transforms have been defined in `data_load.py` and you **do not** need to modify these; take a look at this file (you'll see the same transforms that were defined and applied in Notebook 1).
#
# To define the data transform below, use a [composition](http://pytorch.org/tutorials/beginner/data_loading_tutorial.html#compose-transforms) of:
# 1. Rescaling and/or cropping the data, such that you are left with a square image (the suggested size is 224x224px)
# 2. Normalizing the images and keypoints; turning each RGB image into a grayscale image with a color range of [0, 1] and transforming the given keypoints into a range of [-1, 1]
# 3. Turning these images and keypoints into Tensors
#
# These transformations have been defined in `data_load.py`, but it's up to you to call them and create a `data_transform` below. **This transform will be applied to the training data and, later, the test data**. It will change how you go about displaying these images and keypoints, but these steps are essential for efficient training.
#
# As a note, should you want to perform data augmentation (which is optional in this project), and randomly rotate or shift these images, a square image size will be useful; rotating a 224x224 image by 90 degrees will result in the same shape of output.

# %%
from torch.utils.data import Dataset, DataLoader


# the dataset we created in Notebook 1 is copied in the helper file `data_load.py`
from data_load import FacialKeypointsDataset
# the transforms we defined in Notebook 1 are in the helper file `data_load.py`
from data_load import Rescale, RandomCrop, Normalize, ToTensor,Brightness,RandomFlip


## define the data_transform using transforms.Compose([all tx's, . , .])
# order matters! i.e. rescaling should come before a smaller crop
#train_transform = None

scalesize = 250
cropsize = 224


train_transform = transforms.Compose([
                                     #Rescale(250),#250,136
                                     #RandomCrop(224),#224,96
                                     Rescale(scalesize),#250,136
                                     RandomCrop(cropsize),#224,96
                                     RandomFlip(),
                                     Brightness(0.7),                                     
                                     Normalize(cropsize),
                                     ToTensor()
                                    ])

test_transform = transforms.Compose([ #transforms.RandomRotation(30),
                                     #Rescale(250),
                                     #RandomCrop(224),
                                     Rescale(scalesize),#250,136
                                     RandomCrop(cropsize),#224,96
                                     Normalize(cropsize),
                                     ToTensor()])



# testing that you've defined a transform
#assert(data_transform is not None), 'Define a data_transform'
assert(train_transform is not None), 'Define a data_transform'
assert(test_transform is not None), 'Define a data_transform'

# %%
# create the transformed dataset
train_transformed_dataset = FacialKeypointsDataset(csv_file='data/training_frames_keypoints.csv',
                                             root_dir='data/training/',
                                             transform=train_transform)


print('Number of images: ', len(train_transformed_dataset))

# iterate through the transformed dataset and print some stats about the first few samples
for i in range(4):
    sample = train_transformed_dataset[i]
    print(i, sample['image'].size(), sample['keypoints'].size())
# Out:
# Number of images:  3531
# 0 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 1 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 2 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 3 torch.Size([1, 224, 224]) torch.Size([68, 2])

# %% [markdown]
# ## Batching and loading data
#
# Next, having defined the transformed dataset, we can use PyTorch's DataLoader class to load the training data in batches of whatever size as well as to shuffle the data for training the model. You can read more about the parameters of the DataLoader, in [this documentation](http://pytorch.org/docs/master/data.html).
#
# #### Batch size
# Decide on a good batch size for training your model. Try both small and large batch sizes and note how the loss decreases as the model trains.
#
# **Note for Windows users**: Please change the `num_workers` to 0 or you may face some issues with your DataLoader failing.

# %%
# load training data in batches
train_batch_size = 64#10

train_loader = DataLoader(train_transformed_dataset, 
                          batch_size=train_batch_size,
                          shuffle=True, 
                          num_workers=4)

# %% [markdown]
# ## Before training
#
# Take a look at how this model performs before it trains. You should see that the keypoints it predicts start off in one spot and don't match the keypoints on a face at all! It's interesting to visualize this behavior so that you can compare it to the model after training and see how the model has improved.
#
# #### Load in the test dataset
#
# The test dataset is one that this model has *not* seen before, meaning it has not trained with these images. We'll load in this test data and before and after training, see how your model performs on this set!
#
# To visualize this test data, we have to go through some un-transformation steps to turn our images into python images from tensors and to turn our keypoints back into a recognizable range.

# %%
# load in the test data, using the dataset class
# AND apply the data_transform you defined above

# create the test dataset
test_transformed_dataset = FacialKeypointsDataset(csv_file='data/test_frames_keypoints.csv',
                                             root_dir='data/test/',
                                             transform=test_transform)

print('Number of images: ', len(test_transformed_dataset))

# iterate through the transformed dataset and print some stats about the first few samples
for i in range(4):
    sample = test_transformed_dataset[i]
    print(i, sample['image'].size(), sample['keypoints'].size())
# Out:
# Number of images:  770
# 0 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 1 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 2 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 3 torch.Size([1, 224, 224]) torch.Size([68, 2])

# %%
# load test data in batches
test_batch_size = 10

test_loader = DataLoader(test_transformed_dataset, 
                          batch_size=test_batch_size,
                          shuffle=True, 
                          num_workers=4)

# %% [markdown]
# ## Apply the model on a test sample
#
# To test the model on a test sample of data, you have to follow these steps:
# 1. Extract the image and ground truth keypoints from a sample
# 2. Make sure the image is a FloatTensor, which the model expects.
# 3. Forward pass the image through the net to get the predicted, output keypoints.
#
# This function test how the network performs on the first batch of test data. It returns the images, the transformed images, the predicted keypoints (produced by the model), and the ground truth keypoints.

# %%
# test the model on a batch of test images

def net_sample_output():
    
    # iterate through the test dataset
    for i, sample in enumerate(test_loader):
        
        # get sample data: images and ground truth keypoints
        images = sample['image']
        key_pts = sample['keypoints']
        #print(type(images))
        # convert images to FloatTensors
        images = images.type(torch.cuda.FloatTensor)
        #images = images.to(device)

        key_pts = key_pts.type(torch.cuda.FloatTensor)

        # forward pass to get net output
        output_pts,out1,out2,out3,out4 = net.forward(images.to(device))
        print(out1.data.size())
        feature_map = [out1,out2,out3,out4]
        
        # reshape to batch_size x 68 x 2 pts
        output_pts = output_pts.view(output_pts.size()[0], 68, -1)
        
        # break after first image is tested
        if i == 0:
            return images, output_pts, key_pts,feature_map

# %% [markdown]
# #### Debugging tips
#
# If you get a size or dimension error here, make sure that your network outputs the expected number of keypoints! Or if you get a Tensor type error, look into changing the above code that casts the data into float types: `images = images.type(torch.FloatTensor)`.

# %%
# call the above function
# returns: test images, test predicted keypoints, test ground truth keypoints
test_images, test_outputs, gt_pts,feature_map = net_sample_output()

# print out the dimensions of the data to see if they make sense
print(test_images.data.size())
print(test_outputs.data.size())
print(gt_pts.size())
# Out:
# torch.Size([10, 32, 110, 110])
# torch.Size([10, 1, 224, 224])
# torch.Size([10, 68, 2])
# torch.Size([10, 68, 2])

# %% [markdown]
# ## Visualize the predicted keypoints
#
# Once we've had the model produce some predicted output keypoints, we can visualize these points in a way that's similar to how we've displayed this data before, only this time, we have to "un-transform" the image/keypoint data to display it.
#
# Note that I've defined a *new* function, `show_all_keypoints` that displays a grayscale image, its predicted keypoints and its ground truth keypoints (if provided).

# %%
def show_all_keypoints(image, predicted_key_pts, gt_pts=None):
    """Show image with predicted keypoints"""
    # image is grayscale
    plt.imshow(image, cmap='gray')
    plt.scatter(predicted_key_pts[:, 0], predicted_key_pts[:, 1], s=20, marker='.', c='m')
    # plot ground truth points as green pts
    if gt_pts is not None:
        plt.scatter(gt_pts[:, 0], gt_pts[:, 1], s=20, marker='.', c='g')

# %% [markdown]
# #### Un-transformation
#
# Next, you'll see a helper function. `visualize_output` that takes in a batch of images, predicted keypoints, and ground truth keypoints and displays a set of those images and their true/predicted keypoints.
#
# This function's main role is to take batches of image and keypoint data (the input and output of your CNN), and transform them into numpy images and un-normalized keypoints (x, y) for normal display. The un-transformation process turns keypoints and images into numpy arrays from Tensors *and* it undoes the keypoint normalization done in the Normalize() transform; it's assumed that you applied these transformations when you loaded your test data.

# %%
# visualize the output
# by default this shows a batch of 10 images
def visualize_output(test_images, test_outputs, gt_pts=None, batch_size=10):

    for i in range(batch_size):
        plt.figure(figsize=(80,50))
        ax = plt.subplot(1, batch_size, i+1)

        # un-transform the image data
        image = test_images[i].data   # get the image from it's wrapper
        #image = image.numpy()   # convert to numpy array from a Tensor
        image = image.cpu().numpy()  #for GPU to CPU
        image = np.transpose(image, (1, 2, 0))   # transpose to go from torch to numpy image

        # un-transform the predicted key_pts data
        predicted_key_pts = test_outputs[i].data
        #predicted_key_pts = predicted_key_pts.numpy()
        predicted_key_pts = predicted_key_pts.cpu().numpy()

        # undo normalization of keypoints
        mean  = cropsize/2#50#100,50
        std = cropsize/2#15#50,15
        predicted_key_pts = predicted_key_pts*std+mean
        
        # plot ground truth points for comparison, if they exist
        ground_truth_pts = None
        if gt_pts is not None:
            ground_truth_pts = gt_pts[i]         
            ground_truth_pts = ground_truth_pts*std+mean
        
        # call show_all_keypoints
        show_all_keypoints(np.squeeze(image), predicted_key_pts, ground_truth_pts)
            
        plt.axis('off')

    plt.show()
    
# call it
visualize_output(test_images, test_outputs, gt_pts)

# %% [markdown]
# ## Training
#
# #### Loss function
# Training a network to predict keypoints is different than training a network to predict a class; instead of outputting a distribution of classes and using cross entropy loss, you may want to choose a loss function that is suited for regression, which directly compares a predicted value and target value. Read about the various kinds of loss functions (like MSE or L1/SmoothL1 loss) in [this documentation](http://pytorch.org/docs/master/_modules/torch/nn/modules/loss.html).
#
# ### Define the loss and optimization
#
# Next, you'll define how the model will train by deciding on the loss function and optimizer.
#
# ---

# %%
## TODO: Define the loss and optimization
import torch.optim as optim

learning_rate = 0.0002
criterion = nn.MSELoss()
#criterion = nn.L1Loss()

#optimizer = optim.RMSprop(net.parameters(), lr=learning_rate)
optimizer = optim.Adam(net.parameters(), lr=learning_rate)

# %% [markdown]
# ## Training and Initial Observation
#
# Now, you'll train on your batched training data from `train_loader` for a number of epochs.
#
# To quickly observe how your model is training and decide on whether or not you should modify it's structure or hyperparameters, you're encouraged to start off with just one or two epochs at first. As you train, note how your the model's loss behaves over time: does it decrease quickly at first and then slow down? Does it take a while to decrease in the first place? What happens if you change the batch size of your training data or modify your loss function? etc.
#
# Use these initial observations to make changes to your model and decide on the best architecture before you train for many epochs and create a final model.

# %%
def train_net(n_epochs):
    print_every = 40
    save_every = 100
    steps = 0
    running_loss = 0
    # prepare the net for training
    net.train()

    for epoch in range(n_epochs):  # loop over the dataset multiple times
        
        start_t = time.time()

        # train on batches of data, assumes you already have train_loader
        for batch_i, data in enumerate(train_loader):
            steps += 1

            # get the input images and their corresponding labels
            images = data['image']
            key_pts = data['keypoints']

            # flatten pts
            key_pts = key_pts.view(key_pts.size(0), -1)

            # convert variables to floats for regression loss
            key_pts = key_pts.type(torch.FloatTensor)
            images = images.type(torch.FloatTensor)

            # forward pass to get outputs
            #output_pts = net(images)
            output_pts,_,_,_,_ = net.forward(images.to(device))#.to(device) is for using GPU

            # calculate the loss between predicted and target keypoints
            #loss = criterion(output_pts, key_pts)
            loss = criterion(output_pts, key_pts.to(device))#.to(device) is for using GPU

            # zero the parameter (weight) gradients
            optimizer.zero_grad()
            
            # backward pass to calculate the weight gradients
            loss.backward()

            # update the weights
            optimizer.step()

            # print loss statistics
            # to convert loss into a scalar and add it to the running_loss, use .item()
            running_loss += loss.item()
            
            if steps % print_every == 0:
                # Model in inference mode, dropout is off
                net.eval()

                accuracy = 0
                test_loss = 0
                #for ii, (images, labels) in enumerate(testloader):
                for batch_it, datat in enumerate(test_loader):
                    # get sample data: images and ground truth keypoints
                    images = datat['image']
                    key_pts = datat['keypoints']

                    # convert images to FloatTensors
                    images = images.type(torch.FloatTensor)
                    #images = images.resize_(1, 224,224)
                    #images = images.to(device)

                    key_pts = key_pts.type(torch.FloatTensor)

                    # forward pass to get net output
                    output_pts,_,_,_,_ = net.forward(images.to(device))
                    #output_pts = net.forward(images.to(device))

                    # reshape to batch_size x 68 x 2 pts
                    output_pts = output_pts.view(output_pts.size()[0], 68, -1)

                    loss = criterion(output_pts, key_pts.to(device))#.to(device) is for using GPU 
                    # to convert loss into a scalar and add it to the running_loss, use .item()
                    test_loss += loss.item()
                    #print('testing Avg. Loss: {:f}'.format(running_loss/1000))
                    #running_loss = 0.0

                train_avg_loss=running_loss/print_every
                test_avg_loss = test_loss/len(test_loader)
                print("Epoch: {}/{}.. ".format(epoch+1, n_epochs),
                      "Training Loss: {:.5f}.. ".format(train_avg_loss),
                      "Test Loss: {:.5f}.. ".format(test_avg_loss),
                      #"Test Accuracy: {:.3f}".format(accuracy/len(testloader))
                         )
                train_avgloss_list.append(train_avg_loss)
                test_avgloss_list.append(test_avg_loss)

                running_loss = 0

                # Make sure dropout is on for training
                net.train()
                
        time_cost = time.time() - start_t
        print("1 Epoch time cost {:.3f}".format(time_cost))
        
        if (epoch+1) % save_every == 0:
            save_time = datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")
            #print(save_time)
            ## TODO: change the name to something uniqe for each new model
            model_dir = 'saved_models/'
            model_name = save_time+'_keypoints_model_'+'e'+str(epoch)+'totale'+str(n_epochs)+'_'+str(train_batch_size)+'_l_'+str(learning_rate)+'.pt'
            print(model_name)
            # after training, save your model parameters in the dir 'saved_models'
            torch.save(net.state_dict(), model_dir+model_name)

    print('Finished Training')

# %%
# train your network
n_epochs = 400 # start small, and increase when you've decided on your model structure and hyperparams

train_avgloss_list =[]
test_avgloss_list =[]

start_t = time.time()

train_net(n_epochs)

time_cost = time.time() - start_t
print("Total time cost",time_cost)

net.eval()
# Out:
# Epoch: 1/400..  Training Loss: 0.07070..  Test Loss: 0.03015..
# 1 Epoch time cost 8.942
# Epoch: 2/400..  Training Loss: 0.02943..  Test Loss: 0.01860..
# 1 Epoch time cost 8.645
# Epoch: 3/400..  Training Loss: 0.02131..  Test Loss: 0.01275..
# Epoch: 3/400..  Training Loss: 0.01800..  Test Loss: 0.01014..
# 1 Epoch time cost 9.628
# Epoch: 4/400..  Training Loss: 0.01693..  Test Loss: 0.01002..
# 1 Epoch time cost 8.847
# Epoch: 5/400..  Training Loss: 0.01382..  Test Loss: 0.01197..
# Epoch: 5/400..  Training Loss: 0.01361..  Test Loss: 0.01033..
# 1 Epoch time cost 9.472
# Epoch: 6/400..  Training Loss: 0.01223..  Test Loss: 0.00979..
# 1 Epoch time cost 8.740
# Epoch: 7/400..  Training Loss: 0.01748..  Test Loss: 0.00861..
# 1 Epoch time cost 8.747
# Epoch: 8/400..  Training Loss: 0.01311..  Test Loss: 0.00753..
# Epoch: 8/400..  Training Loss: 0.01219..  Test Loss: 0.00591..
# 1 Epoch time cost 9.334
# Epoch: 9/400..  Training Loss: 0.01003..  Test Loss: 0.00566..
# 1 Epoch time cost 8.518
# Epoch: 10/400..  Training Loss: 0.01172..  Test Loss: 0.00826..
# Epoch: 10/400..  Training Loss: 0.01114..  Test Loss: 0.00583..
# 1 Epoch time cost 9.271
# Epoch: 11/400..  Training Loss: 0.01098..  Test Loss: 0.00562..
# 1 Epoch time cost 8.523
# Epoch: 12/400..  Training Loss: 0.00923..  Test Loss: 0.00585..
# 1 Epoch time cost 8.513
# Epoch: 13/400..  Training Loss: 0.01063..  Test Loss: 0.00748..
# Epoch: 13/400..  Training Loss: 0.00940..  Test Loss: 0.00552..
# 1 Epoch time cost 9.323
# Epoch: 14/400..  Training Loss: 0.00979..  Test Loss: 0.00572..
# 1 Epoch time cost 8.519
# Epoch: 15/400..  Training Loss: 0.00845..  Test Loss: 0.00425..
# Epoch: 15/400..  Training Loss: 0.01031..  Test Loss: 0.00528..
# 1 Epoch time cost 9.299
# Epoch: 16/400..  Training Loss: 0.00838..  Test Loss: 0.00471..
# 1 Epoch time cost 8.527
# Epoch: 17/400..  Training Loss: 0.00846..  Test Loss: 0.00525..
# 1 Epoch time cost 8.529
# Epoch: 18/400..  Training Loss: 0.00855..  Test Loss: 0.00503..
# Epoch: 18/400..  Training Loss: 0.00749..  Test Loss: 0.00457..
# 1 Epoch time cost 9.297
# Epoch: 19/400..  Training Loss: 0.00875..  Test Loss: 0.00547..
# 1 Epoch time cost 8.672
# Epoch: 20/400..  Training Loss: 0.00870..  Test Loss: 0.00608..
# Epoch: 20/400..  Training Loss: 0.00780..  Test Loss: 0.00507..
# 1 Epoch time cost 9.851
# Epoch: 21/400..  Training Loss: 0.00842..  Test Loss: 0.00426..
# 1 Epoch time cost 8.898
# Epoch: 22/400..  Training Loss: 0.00828..  Test Loss: 0.00736..
# 1 Epoch time cost 8.620
# Epoch: 23/400..  Training Loss: 0.00659..  Test Loss: 0.00381..
# Epoch: 23/400..  Training Loss: 0.00662..  Test Loss: 0.00661..
# 1 Epoch time cost 9.537
# Epoch: 24/400..  Training Loss: 0.00691..  Test Loss: 0.00533..
# 1 Epoch time cost 8.597
# Epoch: 25/400..  Training Loss: 0.00758..  Test Loss: 0.00586..
# Epoch: 25/400..  Training Loss: 0.00753..  Test Loss: 0.00542..
# 1 Epoch time cost 9.453
# Epoch: 26/400..  Training Loss: 0.00738..  Test Loss: 0.00531..
# 1 Epoch time cost 8.609
# Epoch: 27/400..  Training Loss: 0.00669..  Test Loss: 0.00366..
# 1 Epoch time cost 8.717
# Epoch: 28/400..  Training Loss: 0.00646..  Test Loss: 0.00338..
# Epoch: 28/400..  Training Loss: 0.00718..  Test Loss: 0.00544..
# 1 Epoch time cost 9.649
# Epoch: 29/400..  Training Loss: 0.00593..  Test Loss: 0.00395..
# 1 Epoch time cost 8.834
# Epoch: 30/400..  Training Loss: 0.00684..  Test Loss: 0.00710..
# Epoch: 30/400..  Training Loss: 0.00749..  Test Loss: 0.00588..
# 1 Epoch time cost 9.444
# Epoch: 31/400..  Training Loss: 0.00627..  Test Loss: 0.00311..
# 1 Epoch time cost 8.568
# Epoch: 32/400..  Training Loss: 0.00805..  Test Loss: 0.00528..
# 1 Epoch time cost 8.745
# Epoch: 33/400..  Training Loss: 0.00780..  Test Loss: 0.00429..
# Epoch: 33/400..  Training Loss: 0.00717..  Test Loss: 0.00373..
# 1 Epoch time cost 9.426
# Epoch: 34/400..  Training Loss: 0.00960..  Test Loss: 0.00590..
# 1 Epoch time cost 8.648
# Epoch: 35/400..  Training Loss: 0.00700..  Test Loss: 0.00306..
# Epoch: 35/400..  Training Loss: 0.00643..  Test Loss: 0.00638..
# 1 Epoch time cost 9.466
# Epoch: 36/400..  Training Loss: 0.00583..  Test Loss: 0.00656..
# 1 Epoch time cost 8.822
# Epoch: 37/400..  Training Loss: 0.00589..  Test Loss: 0.00260..
# 1 Epoch time cost 8.550
# Epoch: 38/400..  Training Loss: 0.00817..  Test Loss: 0.00411..
# Epoch: 38/400..  Training Loss: 0.00678..  Test Loss: 0.00271..
# 1 Epoch time cost 9.327
# Epoch: 39/400..  Training Loss: 0.00862..  Test Loss: 0.00495..
# 1 Epoch time cost 8.546
# Epoch: 40/400..  Training Loss: 0.00672..  Test Loss: 0.00388..
# Epoch: 40/400..  Training Loss: 0.00658..  Test Loss: 0.00546..
# 1 Epoch time cost 9.327
# Epoch: 41/400..  Training Loss: 0.00617..  Test Loss: 0.00338..
# 1 Epoch time cost 8.550
# Epoch: 42/400..  Training Loss: 0.00545..  Test Loss: 0.00304..
# 1 Epoch time cost 8.534
# Epoch: 43/400..  Training Loss: 0.00648..  Test Loss: 0.00430..
# Epoch: 43/400..  Training Loss: 0.00596..  Test Loss: 0.00413..
# 1 Epoch time cost 9.350
# Epoch: 44/400..  Training Loss: 0.00580..  Test Loss: 0.00342..
# 1 Epoch time cost 8.542
# Epoch: 45/400..  Training Loss: 0.00653..  Test Loss: 0.00265..
# Epoch: 45/400..  Training Loss: 0.00660..  Test Loss: 0.00274..
# 1 Epoch time cost 9.303
# Epoch: 46/400..  Training Loss: 0.00718..  Test Loss: 0.00512..
# 1 Epoch time cost 8.559
# Epoch: 47/400..  Training Loss: 0.00679..  Test Loss: 0.00321..
# 1 Epoch time cost 8.557
# Epoch: 48/400..  Training Loss: 0.00524..  Test Loss: 0.00423..
# Epoch: 48/400..  Training Loss: 0.00640..  Test Loss: 0.00318..
# 1 Epoch time cost 9.342
# Epoch: 49/400..  Training Loss: 0.00600..  Test Loss: 0.00337..
# 1 Epoch time cost 8.554
# Epoch: 50/400..  Training Loss: 0.00643..  Test Loss: 0.00476..
# Epoch: 50/400..  Training Loss: 0.00575..  Test Loss: 0.00268..
# 1 Epoch time cost 9.323
# Epoch: 51/400..  Training Loss: 0.00638..  Test Loss: 0.00391..
# 1 Epoch time cost 8.543
# Epoch: 52/400..  Training Loss: 0.00544..  Test Loss: 0.00246..
# 1 Epoch time cost 8.545
# Epoch: 53/400..  Training Loss: 0.00707..  Test Loss: 0.00386..
# Epoch: 53/400..  Training Loss: 0.00568..  Test Loss: 0.00348..
# 1 Epoch time cost 9.332
# Epoch: 54/400..  Training Loss: 0.00718..  Test Loss: 0.00512..
# 1 Epoch time cost 8.538
# Epoch: 55/400..  Training Loss: 0.00554..  Test Loss: 0.00360..
# Epoch: 55/400..  Training Loss: 0.00660..  Test Loss: 0.00384..
# 1 Epoch time cost 9.332
# Epoch: 56/400..  Training Loss: 0.00555..  Test Loss: 0.00439..
# 1 Epoch time cost 8.564
# Epoch: 57/400..  Training Loss: 0.00680..  Test Loss: 0.00327..
# 1 Epoch time cost 8.549
# Epoch: 58/400..  Training Loss: 0.00530..  Test Loss: 0.00224..
# Epoch: 58/400..  Training Loss: 0.00497..  Test Loss: 0.00222..
# 1 Epoch time cost 9.331
# Epoch: 59/400..  Training Loss: 0.00540..  Test Loss: 0.00268..
# 1 Epoch time cost 8.565
# Epoch: 60/400..  Training Loss: 0.00552..  Test Loss: 0.00266..
# Epoch: 60/400..  Training Loss: 0.00609..  Test Loss: 0.00617..
# 1 Epoch time cost 9.996
# Epoch: 61/400..  Training Loss: 0.00497..  Test Loss: 0.00250..
# 1 Epoch time cost 9.060
# Epoch: 62/400..  Training Loss: 0.00545..  Test Loss: 0.00396..
# 1 Epoch time cost 8.591
# Epoch: 63/400..  Training Loss: 0.00581..  Test Loss: 0.00248..
# Epoch: 63/400..  Training Loss: 0.00555..  Test Loss: 0.00313..
# 1 Epoch time cost 9.335
# Epoch: 64/400..  Training Loss: 0.00504..  Test Loss: 0.00224..
# 1 Epoch time cost 8.576
# Epoch: 65/400..  Training Loss: 0.00500..  Test Loss: 0.00391..
# Epoch: 65/400..  Training Loss: 0.00587..  Test Loss: 0.00360..
# 1 Epoch time cost 9.339
# Epoch: 66/400..  Training Loss: 0.00552..  Test Loss: 0.00243..
# 1 Epoch time cost 8.565
# Epoch: 67/400..  Training Loss: 0.00512..  Test Loss: 0.00215..
# 1 Epoch time cost 8.573
# Epoch: 68/400..  Training Loss: 0.00598..  Test Loss: 0.00310..
# Epoch: 68/400..  Training Loss: 0.00490..  Test Loss: 0.00248..
# 1 Epoch time cost 9.320
# Epoch: 69/400..  Training Loss: 0.00416..  Test Loss: 0.00237..
# 1 Epoch time cost 8.551
# Epoch: 70/400..  Training Loss: 0.00470..  Test Loss: 0.00349..
# Epoch: 70/400..  Training Loss: 0.00628..  Test Loss: 0.00336..
# 1 Epoch time cost 9.325
# Epoch: 71/400..  Training Loss: 0.00523..  Test Loss: 0.00288..
# 1 Epoch time cost 8.553
# Epoch: 72/400..  Training Loss: 0.00603..  Test Loss: 0.00702..
# 1 Epoch time cost 8.568
# Epoch: 73/400..  Training Loss: 0.00518..  Test Loss: 0.00525..
# Epoch: 73/400..  Training Loss: 0.00522..  Test Loss: 0.00240..
# 1 Epoch time cost 9.359
# Epoch: 74/400..  Training Loss: 0.00495..  Test Loss: 0.00320..
# 1 Epoch time cost 8.554
# Epoch: 75/400..  Training Loss: 0.00496..  Test Loss: 0.00551..
# Epoch: 75/400..  Training Loss: 0.00510..  Test Loss: 0.00252..
# 1 Epoch time cost 9.334
# Epoch: 76/400..  Training Loss: 0.00548..  Test Loss: 0.00352..
# 1 Epoch time cost 8.536
# Epoch: 77/400..  Training Loss: 0.00489..  Test Loss: 0.00242..
# 1 Epoch time cost 8.552
# Epoch: 78/400..  Training Loss: 0.00583..  Test Loss: 0.00293..
# Epoch: 78/400..  Training Loss: 0.00451..  Test Loss: 0.00300..
# 1 Epoch time cost 9.327
# Epoch: 79/400..  Training Loss: 0.00459..  Test Loss: 0.00312..
# 1 Epoch time cost 8.543
# Epoch: 80/400..  Training Loss: 0.00556..  Test Loss: 0.00292..
# Epoch: 80/400..  Training Loss: 0.00486..  Test Loss: 0.00429..
# 1 Epoch time cost 9.339
# Epoch: 81/400..  Training Loss: 0.00533..  Test Loss: 0.00345..
# 1 Epoch time cost 8.563
# Epoch: 82/400..  Training Loss: 0.00488..  Test Loss: 0.00219..
# 1 Epoch time cost 8.556
# Epoch: 83/400..  Training Loss: 0.00416..  Test Loss: 0.00260..
# Epoch: 83/400..  Training Loss: 0.00441..  Test Loss: 0.00266..
# 1 Epoch time cost 9.349
# Epoch: 84/400..  Training Loss: 0.00651..  Test Loss: 0.00458..
# 1 Epoch time cost 8.548
# Epoch: 85/400..  Training Loss: 0.00481..  Test Loss: 0.00285..
# Epoch: 85/400..  Training Loss: 0.00605..  Test Loss: 0.00338..
# 1 Epoch time cost 9.331
# Epoch: 86/400..  Training Loss: 0.00483..  Test Loss: 0.00339..
# 1 Epoch time cost 8.557
# Epoch: 87/400..  Training Loss: 0.00527..  Test Loss: 0.00199..
# 1 Epoch time cost 8.550
# Epoch: 88/400..  Training Loss: 0.00505..  Test Loss: 0.00386..
# Epoch: 88/400..  Training Loss: 0.00446..  Test Loss: 0.00284..
# 1 Epoch time cost 9.334
# Epoch: 89/400..  Training Loss: 0.00484..  Test Loss: 0.00269..
# 1 Epoch time cost 8.553
# Epoch: 90/400..  Training Loss: 0.00531..  Test Loss: 0.00253..
# Epoch: 90/400..  Training Loss: 0.00527..  Test Loss: 0.00241..
# 1 Epoch time cost 9.326
# Epoch: 91/400..  Training Loss: 0.00451..  Test Loss: 0.00215..
# 1 Epoch time cost 8.554
# Epoch: 92/400..  Training Loss: 0.00452..  Test Loss: 0.00225..
# 1 Epoch time cost 8.547
# Epoch: 93/400..  Training Loss: 0.00509..  Test Loss: 0.00242..
# Epoch: 93/400..  Training Loss: 0.00560..  Test Loss: 0.00202..
# 1 Epoch time cost 9.353
# Epoch: 94/400..  Training Loss: 0.00452..  Test Loss: 0.00255..
# 1 Epoch time cost 8.543
# Epoch: 95/400..  Training Loss: 0.00526..  Test Loss: 0.00432..
# Epoch: 95/400..  Training Loss: 0.00596..  Test Loss: 0.00475..
# 1 Epoch time cost 9.325
# Epoch: 96/400..  Training Loss: 0.00481..  Test Loss: 0.00277..
# 1 Epoch time cost 8.544
# Epoch: 97/400..  Training Loss: 0.00452..  Test Loss: 0.00186..
# 1 Epoch time cost 8.564
# Epoch: 98/400..  Training Loss: 0.00448..  Test Loss: 0.00190..
# Epoch: 98/400..  Training Loss: 0.00509..  Test Loss: 0.00303..
# 1 Epoch time cost 9.335
# Epoch: 99/400..  Training Loss: 0.00478..  Test Loss: 0.00244..
# 1 Epoch time cost 8.555
# Epoch: 100/400..  Training Loss: 0.00445..  Test Loss: 0.00216..
# Epoch: 100/400..  Training Loss: 0.00448..  Test Loss: 0.00216..
# 1 Epoch time cost 9.553
# 2018-05-06-21-49-13_keypoints_model_e99totale400_64_l_0.0002.pt
# Epoch: 101/400..  Training Loss: 0.00392..  Test Loss: 0.00211..
# 1 Epoch time cost 8.504
# Epoch: 102/400..  Training Loss: 0.00514..  Test Loss: 0.00352..
# 1 Epoch time cost 8.560
# Epoch: 103/400..  Training Loss: 0.00443..  Test Loss: 0.00218..
# Epoch: 103/400..  Training Loss: 0.00401..  Test Loss: 0.00181..
# 1 Epoch time cost 9.347
# Epoch: 104/400..  Training Loss: 0.00413..  Test Loss: 0.00185..
# 1 Epoch time cost 8.656
# Epoch: 105/400..  Training Loss: 0.00385..  Test Loss: 0.00189..
# Epoch: 105/400..  Training Loss: 0.00404..  Test Loss: 0.00217..
# 1 Epoch time cost 9.365
# Epoch: 106/400..  Training Loss: 0.00436..  Test Loss: 0.00180..
# 1 Epoch time cost 8.557
# Epoch: 107/400..  Training Loss: 0.00820..  Test Loss: 0.00315..
# 1 Epoch time cost 8.561
# Epoch: 108/400..  Training Loss: 0.00510..  Test Loss: 0.00220..
# Epoch: 108/400..  Training Loss: 0.00421..  Test Loss: 0.00208..
# 1 Epoch time cost 9.334
# Epoch: 109/400..  Training Loss: 0.00418..  Test Loss: 0.00221..
# 1 Epoch time cost 8.546
# Epoch: 110/400..  Training Loss: 0.00413..  Test Loss: 0.00207..
# Epoch: 110/400..  Training Loss: 0.00415..  Test Loss: 0.00217..
# 1 Epoch time cost 9.318
# Epoch: 111/400..  Training Loss: 0.00466..  Test Loss: 0.00433..
# 1 Epoch time cost 8.557
# Epoch: 112/400..  Training Loss: 0.00445..  Test Loss: 0.00272..
# 1 Epoch time cost 8.552
# Epoch: 113/400..  Training Loss: 0.00380..  Test Loss: 0.00323..
# Epoch: 113/400..  Training Loss: 0.00418..  Test Loss: 0.00177..
# 1 Epoch time cost 9.336
# Epoch: 114/400..  Training Loss: 0.00416..  Test Loss: 0.00180..
# 1 Epoch time cost 8.550
# Epoch: 115/400..  Training Loss: 0.00500..  Test Loss: 0.00190..
# Epoch: 115/400..  Training Loss: 0.00429..  Test Loss: 0.00582..
# 1 Epoch time cost 9.341
# Epoch: 116/400..  Training Loss: 0.00397..  Test Loss: 0.00160..
# 1 Epoch time cost 8.544
# Epoch: 117/400..  Training Loss: 0.00402..  Test Loss: 0.00181..
# 1 Epoch time cost 8.548
# Epoch: 118/400..  Training Loss: 0.00438..  Test Loss: 0.00601..
# Epoch: 118/400..  Training Loss: 0.00448..  Test Loss: 0.00178..
# 1 Epoch time cost 9.336
# Epoch: 119/400..  Training Loss: 0.00385..  Test Loss: 0.00191..
# 1 Epoch time cost 8.563
# Epoch: 120/400..  Training Loss: 0.00482..  Test Loss: 0.00477..
# Epoch: 120/400..  Training Loss: 0.00421..  Test Loss: 0.00224..
# 1 Epoch time cost 9.323
# Epoch: 121/400..  Training Loss: 0.00463..  Test Loss: 0.00223..
# 1 Epoch time cost 8.596
# Epoch: 122/400..  Training Loss: 0.00376..  Test Loss: 0.00264..
# 1 Epoch time cost 8.555
# Epoch: 123/400..  Training Loss: 0.00396..  Test Loss: 0.00204..
# Epoch: 123/400..  Training Loss: 0.00369..  Test Loss: 0.00290..
# 1 Epoch time cost 9.329
# Epoch: 124/400..  Training Loss: 0.00442..  Test Loss: 0.00490..
# 1 Epoch time cost 8.552
# Epoch: 125/400..  Training Loss: 0.00462..  Test Loss: 0.00285..
# Epoch: 125/400..  Training Loss: 0.00450..  Test Loss: 0.00609..
# 1 Epoch time cost 9.318
# Epoch: 126/400..  Training Loss: 0.00675..  Test Loss: 0.00787..
# 1 Epoch time cost 8.724
# Epoch: 127/400..  Training Loss: 0.00443..  Test Loss: 0.00181..
# 1 Epoch time cost 8.660
# Epoch: 128/400..  Training Loss: 0.00385..  Test Loss: 0.00641..
# Epoch: 128/400..  Training Loss: 0.00427..  Test Loss: 0.00308..
# 1 Epoch time cost 9.492
# Epoch: 129/400..  Training Loss: 0.00523..  Test Loss: 0.00233..
# 1 Epoch time cost 8.628
# Epoch: 130/400..  Training Loss: 0.00398..  Test Loss: 0.00186..
# Epoch: 130/400..  Training Loss: 0.00386..  Test Loss: 0.00416..
# 1 Epoch time cost 9.393
# Epoch: 131/400..  Training Loss: 0.00379..  Test Loss: 0.00173..
# 1 Epoch time cost 8.542
# Epoch: 132/400..  Training Loss: 0.00412..  Test Loss: 0.00172..
# 1 Epoch time cost 8.551
# Epoch: 133/400..  Training Loss: 0.00375..  Test Loss: 0.00219..
# Epoch: 133/400..  Training Loss: 0.00402..  Test Loss: 0.00184..
# 1 Epoch time cost 9.471
# Epoch: 134/400..  Training Loss: 0.00436..  Test Loss: 0.00205..
# 1 Epoch time cost 8.576
# Epoch: 135/400..  Training Loss: 0.00543..  Test Loss: 0.00219..
# Epoch: 135/400..  Training Loss: 0.00403..  Test Loss: 0.00189..
# 1 Epoch time cost 9.305
# Epoch: 136/400..  Training Loss: 0.00404..  Test Loss: 0.00224..
# 1 Epoch time cost 8.559
# Epoch: 137/400..  Training Loss: 0.00391..  Test Loss: 0.00195..
# 1 Epoch time cost 8.551
# Epoch: 138/400..  Training Loss: 0.00642..  Test Loss: 0.00325..
# Epoch: 138/400..  Training Loss: 0.00401..  Test Loss: 0.00176..
# 1 Epoch time cost 9.339
# Epoch: 139/400..  Training Loss: 0.00413..  Test Loss: 0.00277..
# 1 Epoch time cost 8.548
# Epoch: 140/400..  Training Loss: 0.00418..  Test Loss: 0.00219..
# Epoch: 140/400..  Training Loss: 0.00419..  Test Loss: 0.00205..
# 1 Epoch time cost 9.316
# Epoch: 141/400..  Training Loss: 0.00426..  Test Loss: 0.00189..
# 1 Epoch time cost 8.566
# Epoch: 142/400..  Training Loss: 0.00385..  Test Loss: 0.00228..
# 1 Epoch time cost 8.544
# Epoch: 143/400..  Training Loss: 0.00370..  Test Loss: 0.00182..
# Epoch: 143/400..  Training Loss: 0.00385..  Test Loss: 0.00235..
# 1 Epoch time cost 9.360
# Epoch: 144/400..  Training Loss: 0.00373..  Test Loss: 0.00187..
# 1 Epoch time cost 8.557
# Epoch: 145/400..  Training Loss: 0.00591..  Test Loss: 0.00193..
# Epoch: 145/400..  Training Loss: 0.00419..  Test Loss: 0.00227..
# 1 Epoch time cost 9.320
# Epoch: 146/400..  Training Loss: 0.00404..  Test Loss: 0.00261..
# 1 Epoch time cost 8.560
# Epoch: 147/400..  Training Loss: 0.00366..  Test Loss: 0.00186..
# 1 Epoch time cost 8.536
# Epoch: 148/400..  Training Loss: 0.00412..  Test Loss: 0.00328..
# Epoch: 148/400..  Training Loss: 0.00429..  Test Loss: 0.00200..
# 1 Epoch time cost 9.366
# Epoch: 149/400..  Training Loss: 0.00511..  Test Loss: 0.00180..
# 1 Epoch time cost 8.555
# Epoch: 150/400..  Training Loss: 0.00366..  Test Loss: 0.00169..
# Epoch: 150/400..  Training Loss: 0.00356..  Test Loss: 0.00241..
# 1 Epoch time cost 9.338
# Epoch: 151/400..  Training Loss: 0.00399..  Test Loss: 0.00178..
# 1 Epoch time cost 8.575
# Epoch: 152/400..  Training Loss: 0.00377..  Test Loss: 0.00177..
# 1 Epoch time cost 8.546
# Epoch: 153/400..  Training Loss: 0.00356..  Test Loss: 0.00241..
# Epoch: 153/400..  Training Loss: 0.00389..  Test Loss: 0.00188..
# 1 Epoch time cost 9.320
# Epoch: 154/400..  Training Loss: 0.00387..  Test Loss: 0.00183..
# 1 Epoch time cost 8.552
# Epoch: 155/400..  Training Loss: 0.00373..  Test Loss: 0.00170..
# Epoch: 155/400..  Training Loss: 0.00357..  Test Loss: 0.00224..
# 1 Epoch time cost 9.329
# Epoch: 156/400..  Training Loss: 0.00375..  Test Loss: 0.00180..
# 1 Epoch time cost 8.547
# Epoch: 157/400..  Training Loss: 0.00368..  Test Loss: 0.00202..
# 1 Epoch time cost 8.544
# Epoch: 158/400..  Training Loss: 0.00393..  Test Loss: 0.00164..
# Epoch: 158/400..  Training Loss: 0.00365..  Test Loss: 0.00177..
# 1 Epoch time cost 9.353
# Epoch: 159/400..  Training Loss: 0.00494..  Test Loss: 0.00184..
# 1 Epoch time cost 8.548
# Epoch: 160/400..  Training Loss: 0.00347..  Test Loss: 0.00186..
# Epoch: 160/400..  Training Loss: 0.00372..  Test Loss: 0.00174..
# 1 Epoch time cost 9.336
# Epoch: 161/400..  Training Loss: 0.00414..  Test Loss: 0.00211..
# 1 Epoch time cost 8.588
# Epoch: 162/400..  Training Loss: 0.00360..  Test Loss: 0.00222..
# 1 Epoch time cost 8.552
# Epoch: 163/400..  Training Loss: 0.00387..  Test Loss: 0.00193..
# Epoch: 163/400..  Training Loss: 0.00395..  Test Loss: 0.00217..
# 1 Epoch time cost 9.313
# Epoch: 164/400..  Training Loss: 0.00358..  Test Loss: 0.00180..
# 1 Epoch time cost 8.550
# Epoch: 165/400..  Training Loss: 0.00354..  Test Loss: 0.00179..
# Epoch: 165/400..  Training Loss: 0.00369..  Test Loss: 0.00184..
# 1 Epoch time cost 9.273
# Epoch: 166/400..  Training Loss: 0.00338..  Test Loss: 0.00185..
# 1 Epoch time cost 8.564
# Epoch: 167/400..  Training Loss: 0.00360..  Test Loss: 0.00197..
# 1 Epoch time cost 8.561
# Epoch: 168/400..  Training Loss: 0.00356..  Test Loss: 0.00175..
# Epoch: 168/400..  Training Loss: 0.00387..  Test Loss: 0.00185..
# 1 Epoch time cost 9.340
# Epoch: 169/400..  Training Loss: 0.00382..  Test Loss: 0.00166..
# 1 Epoch time cost 8.547
# Epoch: 170/400..  Training Loss: 0.00324..  Test Loss: 0.00184..
# Epoch: 170/400..  Training Loss: 0.00366..  Test Loss: 0.00158..
# 1 Epoch time cost 9.318
# Epoch: 171/400..  Training Loss: 0.00373..  Test Loss: 0.00197..
# 1 Epoch time cost 8.717
# Epoch: 172/400..  Training Loss: 0.00362..  Test Loss: 0.00184..
# 1 Epoch time cost 8.892
# Epoch: 173/400..  Training Loss: 0.00364..  Test Loss: 0.00161..
# Epoch: 173/400..  Training Loss: 0.00332..  Test Loss: 0.00167..
# 1 Epoch time cost 9.479
# Epoch: 174/400..  Training Loss: 0.00330..  Test Loss: 0.00144..
# 1 Epoch time cost 8.574
# Epoch: 175/400..  Training Loss: 0.00362..  Test Loss: 0.00204..
# Epoch: 175/400..  Training Loss: 0.00346..  Test Loss: 0.00150..
# 1 Epoch time cost 9.445
# Epoch: 176/400..  Training Loss: 0.00382..  Test Loss: 0.00198..
# 1 Epoch time cost 8.653
# Epoch: 177/400..  Training Loss: 0.00456..  Test Loss: 0.00276..
# 1 Epoch time cost 8.562
# Epoch: 178/400..  Training Loss: 0.00438..  Test Loss: 0.00255..
# Epoch: 178/400..  Training Loss: 0.00422..  Test Loss: 0.00174..
# 1 Epoch time cost 9.370
# Epoch: 179/400..  Training Loss: 0.00382..  Test Loss: 0.00184..
# 1 Epoch time cost 8.655
# Epoch: 180/400..  Training Loss: 0.00398..  Test Loss: 0.00173..
# Epoch: 180/400..  Training Loss: 0.00364..  Test Loss: 0.00186..
# 1 Epoch time cost 9.484
# Epoch: 181/400..  Training Loss: 0.00364..  Test Loss: 0.00173..
# 1 Epoch time cost 8.745
# Epoch: 182/400..  Training Loss: 0.00421..  Test Loss: 0.00217..
# 1 Epoch time cost 9.023
# Epoch: 183/400..  Training Loss: 0.00365..  Test Loss: 0.00165..
# Epoch: 183/400..  Training Loss: 0.00342..  Test Loss: 0.00175..
# 1 Epoch time cost 9.468
# Epoch: 184/400..  Training Loss: 0.00341..  Test Loss: 0.00169..
# 1 Epoch time cost 8.592
# Epoch: 185/400..  Training Loss: 0.00356..  Test Loss: 0.00171..
# Epoch: 185/400..  Training Loss: 0.00389..  Test Loss: 0.00182..
# 1 Epoch time cost 9.331
# Epoch: 186/400..  Training Loss: 0.00361..  Test Loss: 0.00163..
# 1 Epoch time cost 8.559
# Epoch: 187/400..  Training Loss: 0.00357..  Test Loss: 0.00202..
# 1 Epoch time cost 8.570
# Epoch: 188/400..  Training Loss: 0.00323..  Test Loss: 0.00156..
# Epoch: 188/400..  Training Loss: 0.00354..  Test Loss: 0.00160..
# 1 Epoch time cost 9.364
# Epoch: 189/400..  Training Loss: 0.00338..  Test Loss: 0.00149..
# 1 Epoch time cost 8.530
# Epoch: 190/400..  Training Loss: 0.00321..  Test Loss: 0.00164..
# Epoch: 190/400..  Training Loss: 0.00469..  Test Loss: 0.00269..
# 1 Epoch time cost 9.321
# Epoch: 191/400..  Training Loss: 0.00344..  Test Loss: 0.00179..
# 1 Epoch time cost 8.570
# Epoch: 192/400..  Training Loss: 0.00368..  Test Loss: 0.00200..
# 1 Epoch time cost 8.539
# Epoch: 193/400..  Training Loss: 0.00373..  Test Loss: 0.00190..
# Epoch: 193/400..  Training Loss: 0.00383..  Test Loss: 0.00193..
# 1 Epoch time cost 9.337
# Epoch: 194/400..  Training Loss: 0.00372..  Test Loss: 0.00382..
# 1 Epoch time cost 8.567
# Epoch: 195/400..  Training Loss: 0.00329..  Test Loss: 0.00189..
# Epoch: 195/400..  Training Loss: 0.00328..  Test Loss: 0.00190..
# 1 Epoch time cost 9.357
# Epoch: 196/400..  Training Loss: 0.00357..  Test Loss: 0.00164..
# 1 Epoch time cost 8.571
# Epoch: 197/400..  Training Loss: 0.00377..  Test Loss: 0.00375..
# 1 Epoch time cost 8.545
# Epoch: 198/400..  Training Loss: 0.00327..  Test Loss: 0.00157..
# Epoch: 198/400..  Training Loss: 0.00328..  Test Loss: 0.00149..
# 1 Epoch time cost 9.342
# Epoch: 199/400..  Training Loss: 0.00344..  Test Loss: 0.00145..
# 1 Epoch time cost 8.558
# Epoch: 200/400..  Training Loss: 0.00407..  Test Loss: 0.00173..
# Epoch: 200/400..  Training Loss: 0.00332..  Test Loss: 0.00179..
# 1 Epoch time cost 9.340
# 2018-05-06-22-04-03_keypoints_model_e199totale400_64_l_0.0002.pt
# Epoch: 201/400..  Training Loss: 0.00333..  Test Loss: 0.00156..
# 1 Epoch time cost 8.488
# Epoch: 202/400..  Training Loss: 0.00371..  Test Loss: 0.00175..
# 1 Epoch time cost 8.576
# Epoch: 203/400..  Training Loss: 0.00335..  Test Loss: 0.00174..
# Epoch: 203/400..  Training Loss: 0.00318..  Test Loss: 0.00154..
# 1 Epoch time cost 9.333
# Epoch: 204/400..  Training Loss: 0.00337..  Test Loss: 0.00145..
# 1 Epoch time cost 8.567
# Epoch: 205/400..  Training Loss: 0.00320..  Test Loss: 0.00148..
# Epoch: 205/400..  Training Loss: 0.00327..  Test Loss: 0.00193..
# 1 Epoch time cost 9.341
# Epoch: 206/400..  Training Loss: 0.00361..  Test Loss: 0.00155..
# 1 Epoch time cost 8.547
# Epoch: 207/400..  Training Loss: 0.00331..  Test Loss: 0.00147..
# 1 Epoch time cost 8.546
# Epoch: 208/400..  Training Loss: 0.00333..  Test Loss: 0.00165..
# Epoch: 208/400..  Training Loss: 0.00353..  Test Loss: 0.00143..
# 1 Epoch time cost 9.341
# Epoch: 209/400..  Training Loss: 0.00318..  Test Loss: 0.00149..
# 1 Epoch time cost 8.554
# Epoch: 210/400..  Training Loss: 0.00363..  Test Loss: 0.00182..
# Epoch: 210/400..  Training Loss: 0.00349..  Test Loss: 0.00146..
# 1 Epoch time cost 9.344
# Epoch: 211/400..  Training Loss: 0.00471..  Test Loss: 0.00212..
# 1 Epoch time cost 8.540
# Epoch: 212/400..  Training Loss: 0.00421..  Test Loss: 0.00285..
# 1 Epoch time cost 8.557
# Epoch: 213/400..  Training Loss: 0.00376..  Test Loss: 0.00165..
# Epoch: 213/400..  Training Loss: 0.00339..  Test Loss: 0.00270..
# 1 Epoch time cost 9.339
# Epoch: 214/400..  Training Loss: 0.00334..  Test Loss: 0.00189..
# 1 Epoch time cost 8.552
# Epoch: 215/400..  Training Loss: 0.00370..  Test Loss: 0.00162..
# Epoch: 215/400..  Training Loss: 0.00333..  Test Loss: 0.00154..
# 1 Epoch time cost 9.356
# Epoch: 216/400..  Training Loss: 0.00508..  Test Loss: 0.00239..
# 1 Epoch time cost 8.567
# Epoch: 217/400..  Training Loss: 0.00397..  Test Loss: 0.00205..
# 1 Epoch time cost 8.553
# Epoch: 218/400..  Training Loss: 0.00773..  Test Loss: 0.01419..
# Epoch: 218/400..  Training Loss: 0.00503..  Test Loss: 0.00216..
# 1 Epoch time cost 9.331
# Epoch: 219/400..  Training Loss: 0.00414..  Test Loss: 0.00497..
# 1 Epoch time cost 8.494
# Epoch: 220/400..  Training Loss: 0.00423..  Test Loss: 0.00233..
# Epoch: 220/400..  Training Loss: 0.00457..  Test Loss: 0.00174..
# 1 Epoch time cost 9.331
# Epoch: 221/400..  Training Loss: 0.00413..  Test Loss: 0.00156..
# 1 Epoch time cost 8.570
# Epoch: 222/400..  Training Loss: 0.00377..  Test Loss: 0.00192..
# 1 Epoch time cost 8.548
# Epoch: 223/400..  Training Loss: 0.00448..  Test Loss: 0.00245..
# Epoch: 223/400..  Training Loss: 0.00439..  Test Loss: 0.00190..
# 1 Epoch time cost 9.332
# Epoch: 224/400..  Training Loss: 0.00352..  Test Loss: 0.00144..
# 1 Epoch time cost 8.537
# Epoch: 225/400..  Training Loss: 0.00403..  Test Loss: 0.00193..
# Epoch: 225/400..  Training Loss: 0.00354..  Test Loss: 0.00150..
# 1 Epoch time cost 9.322
# Epoch: 226/400..  Training Loss: 0.00321..  Test Loss: 0.00153..
# 1 Epoch time cost 8.529
# Epoch: 227/400..  Training Loss: 0.00351..  Test Loss: 0.00147..
# 1 Epoch time cost 8.561
# Epoch: 228/400..  Training Loss: 0.00323..  Test Loss: 0.00147..
# Epoch: 228/400..  Training Loss: 0.00318..  Test Loss: 0.00147..
# 1 Epoch time cost 9.332
# Epoch: 229/400..  Training Loss: 0.00348..  Test Loss: 0.00157..
# 1 Epoch time cost 8.581
# Epoch: 230/400..  Training Loss: 0.00333..  Test Loss: 0.00143..
# Epoch: 230/400..  Training Loss: 0.00309..  Test Loss: 0.00159..
# 1 Epoch time cost 9.338
# Epoch: 231/400..  Training Loss: 0.00328..  Test Loss: 0.00139..
# 1 Epoch time cost 8.552
# Epoch: 232/400..  Training Loss: 0.00329..  Test Loss: 0.00178..
# 1 Epoch time cost 8.564
# Epoch: 233/400..  Training Loss: 0.00320..  Test Loss: 0.00153..
# Epoch: 233/400..  Training Loss: 0.00306..  Test Loss: 0.00135..
# 1 Epoch time cost 9.328
# Epoch: 234/400..  Training Loss: 0.00299..  Test Loss: 0.00143..
# 1 Epoch time cost 8.556
# Epoch: 235/400..  Training Loss: 0.00340..  Test Loss: 0.00164..
# Epoch: 235/400..  Training Loss: 0.00336..  Test Loss: 0.00145..
# 1 Epoch time cost 9.339
# Epoch: 236/400..  Training Loss: 0.00320..  Test Loss: 0.00151..
# 1 Epoch time cost 8.570
# Epoch: 237/400..  Training Loss: 0.00313..  Test Loss: 0.00173..
# 1 Epoch time cost 8.571
# Epoch: 238/400..  Training Loss: 0.00322..  Test Loss: 0.00169..
# Epoch: 238/400..  Training Loss: 0.00305..  Test Loss: 0.00136..
# 1 Epoch time cost 9.333
# Epoch: 239/400..  Training Loss: 0.00312..  Test Loss: 0.00136..
# 1 Epoch time cost 8.558
# Epoch: 240/400..  Training Loss: 0.00319..  Test Loss: 0.00172..
# Epoch: 240/400..  Training Loss: 0.00309..  Test Loss: 0.00288..
# 1 Epoch time cost 9.328
# Epoch: 241/400..  Training Loss: 0.00326..  Test Loss: 0.00146..
# 1 Epoch time cost 8.543
# Epoch: 242/400..  Training Loss: 0.00345..  Test Loss: 0.00144..
# 1 Epoch time cost 8.584
# Epoch: 243/400..  Training Loss: 0.00344..  Test Loss: 0.00152..
# Epoch: 243/400..  Training Loss: 0.00308..  Test Loss: 0.00164..
# 1 Epoch time cost 9.347
# Epoch: 244/400..  Training Loss: 0.00375..  Test Loss: 0.00221..
# 1 Epoch time cost 8.563
# Epoch: 245/400..  Training Loss: 0.00309..  Test Loss: 0.00167..
# Epoch: 245/400..  Training Loss: 0.00307..  Test Loss: 0.00133..
# 1 Epoch time cost 9.326
# Epoch: 246/400..  Training Loss: 0.00321..  Test Loss: 0.00161..
# 1 Epoch time cost 8.551
# Epoch: 247/400..  Training Loss: 0.00333..  Test Loss: 0.00153..
# 1 Epoch time cost 8.565
# Epoch: 248/400..  Training Loss: 0.00308..  Test Loss: 0.00141..
# Epoch: 248/400..  Training Loss: 0.00302..  Test Loss: 0.00139..
# 1 Epoch time cost 9.315
# Epoch: 249/400..  Training Loss: 0.00309..  Test Loss: 0.00132..
# 1 Epoch time cost 8.526
# Epoch: 250/400..  Training Loss: 0.00304..  Test Loss: 0.00156..
# Epoch: 250/400..  Training Loss: 0.00317..  Test Loss: 0.00142..
# 1 Epoch time cost 9.321
# Epoch: 251/400..  Training Loss: 0.00327..  Test Loss: 0.00135..
# 1 Epoch time cost 8.547
# Epoch: 252/400..  Training Loss: 0.00374..  Test Loss: 0.00157..
# 1 Epoch time cost 8.558
# Epoch: 253/400..  Training Loss: 0.00337..  Test Loss: 0.00198..
# Epoch: 253/400..  Training Loss: 0.00345..  Test Loss: 0.00179..
# 1 Epoch time cost 9.333
# Epoch: 254/400..  Training Loss: 0.00313..  Test Loss: 0.00162..
# 1 Epoch time cost 8.564
# Epoch: 255/400..  Training Loss: 0.00346..  Test Loss: 0.00180..
# Epoch: 255/400..  Training Loss: 0.00314..  Test Loss: 0.00125..
# 1 Epoch time cost 9.333
# Epoch: 256/400..  Training Loss: 0.00375..  Test Loss: 0.00232..
# 1 Epoch time cost 8.585
# Epoch: 257/400..  Training Loss: 0.00410..  Test Loss: 0.00201..
# 1 Epoch time cost 8.548
# Epoch: 258/400..  Training Loss: 0.00327..  Test Loss: 0.00148..
# Epoch: 258/400..  Training Loss: 0.00326..  Test Loss: 0.00144..
# 1 Epoch time cost 9.324
# Epoch: 259/400..  Training Loss: 0.00301..  Test Loss: 0.00141..
# 1 Epoch time cost 8.553
# Epoch: 260/400..  Training Loss: 0.00359..  Test Loss: 0.00299..
# Epoch: 260/400..  Training Loss: 0.00377..  Test Loss: 0.00170..
# 1 Epoch time cost 9.264
# Epoch: 261/400..  Training Loss: 0.00327..  Test Loss: 0.00144..
# 1 Epoch time cost 8.531
# Epoch: 262/400..  Training Loss: 0.00309..  Test Loss: 0.00130..
# 1 Epoch time cost 8.611
# Epoch: 263/400..  Training Loss: 0.00312..  Test Loss: 0.00135..
# Epoch: 263/400..  Training Loss: 0.00325..  Test Loss: 0.00163..
# 1 Epoch time cost 9.602
# Epoch: 264/400..  Training Loss: 0.00326..  Test Loss: 0.00209..
# 1 Epoch time cost 8.917
# Epoch: 265/400..  Training Loss: 0.00301..  Test Loss: 0.00154..
# Epoch: 265/400..  Training Loss: 0.00356..  Test Loss: 0.00143..
# 1 Epoch time cost 9.402
# Epoch: 266/400..  Training Loss: 0.00368..  Test Loss: 0.00150..
# 1 Epoch time cost 8.828
# Epoch: 267/400..  Training Loss: 0.00366..  Test Loss: 0.00148..
# 1 Epoch time cost 8.682
# Epoch: 268/400..  Training Loss: 0.00304..  Test Loss: 0.00197..
# Epoch: 268/400..  Training Loss: 0.00331..  Test Loss: 0.00383..
# 1 Epoch time cost 9.467
# Epoch: 269/400..  Training Loss: 0.00320..  Test Loss: 0.00158..
# 1 Epoch time cost 8.740
# Epoch: 270/400..  Training Loss: 0.00301..  Test Loss: 0.00132..
# Epoch: 270/400..  Training Loss: 0.00289..  Test Loss: 0.00148..
# 1 Epoch time cost 9.501
# Epoch: 271/400..  Training Loss: 0.00304..  Test Loss: 0.00176..
# 1 Epoch time cost 8.569
# Epoch: 272/400..  Training Loss: 0.00303..  Test Loss: 0.00174..
# 1 Epoch time cost 8.555
# Epoch: 273/400..  Training Loss: 0.00324..  Test Loss: 0.00164..
# Epoch: 273/400..  Training Loss: 0.00312..  Test Loss: 0.00152..
# 1 Epoch time cost 9.342
# Epoch: 274/400..  Training Loss: 0.00305..  Test Loss: 0.00131..
# 1 Epoch time cost 8.546
# Epoch: 275/400..  Training Loss: 0.00331..  Test Loss: 0.00152..
# Epoch: 275/400..  Training Loss: 0.00330..  Test Loss: 0.00147..
# 1 Epoch time cost 9.782
# Epoch: 276/400..  Training Loss: 0.00299..  Test Loss: 0.00146..
# 1 Epoch time cost 8.810
# Epoch: 277/400..  Training Loss: 0.00308..  Test Loss: 0.00163..
# 1 Epoch time cost 8.734
# Epoch: 278/400..  Training Loss: 0.00476..  Test Loss: 0.00193..
# Epoch: 278/400..  Training Loss: 0.00341..  Test Loss: 0.00154..
# 1 Epoch time cost 9.570
# Epoch: 279/400..  Training Loss: 0.00316..  Test Loss: 0.00189..
# 1 Epoch time cost 8.797
# Epoch: 280/400..  Training Loss: 0.00345..  Test Loss: 0.00147..
# Epoch: 280/400..  Training Loss: 0.00305..  Test Loss: 0.00167..
# 1 Epoch time cost 9.493
# Epoch: 281/400..  Training Loss: 0.00316..  Test Loss: 0.00128..
# 1 Epoch time cost 8.557
# Epoch: 282/400..  Training Loss: 0.00298..  Test Loss: 0.00134..
# 1 Epoch time cost 8.688
# Epoch: 283/400..  Training Loss: 0.00313..  Test Loss: 0.00140..
# Epoch: 283/400..  Training Loss: 0.00316..  Test Loss: 0.00134..
# 1 Epoch time cost 9.446
# Epoch: 284/400..  Training Loss: 0.00359..  Test Loss: 0.00294..
# 1 Epoch time cost 8.771
# Epoch: 285/400..  Training Loss: 0.00383..  Test Loss: 0.00175..
# Epoch: 285/400..  Training Loss: 0.00355..  Test Loss: 0.00152..
# 1 Epoch time cost 9.545
# Epoch: 286/400..  Training Loss: 0.00366..  Test Loss: 0.00131..
# 1 Epoch time cost 8.709
# Epoch: 287/400..  Training Loss: 0.00343..  Test Loss: 0.00152..
# 1 Epoch time cost 8.768
# Epoch: 288/400..  Training Loss: 0.00328..  Test Loss: 0.00153..
# Epoch: 288/400..  Training Loss: 0.00331..  Test Loss: 0.00164..
# 1 Epoch time cost 9.566
# Epoch: 289/400..  Training Loss: 0.00322..  Test Loss: 0.00155..
# 1 Epoch time cost 8.737
# Epoch: 290/400..  Training Loss: 0.00301..  Test Loss: 0.00141..
# Epoch: 290/400..  Training Loss: 0.00286..  Test Loss: 0.00148..
# 1 Epoch time cost 9.521
# Epoch: 291/400..  Training Loss: 0.00297..  Test Loss: 0.00126..
# 1 Epoch time cost 8.653
# Epoch: 292/400..  Training Loss: 0.00317..  Test Loss: 0.00145..
# 1 Epoch time cost 8.741
# Epoch: 293/400..  Training Loss: 0.00319..  Test Loss: 0.00150..
# Epoch: 293/400..  Training Loss: 0.00287..  Test Loss: 0.00125..
# 1 Epoch time cost 9.580
# Epoch: 294/400..  Training Loss: 0.00273..  Test Loss: 0.00132..
# 1 Epoch time cost 8.662
# Epoch: 295/400..  Training Loss: 0.00323..  Test Loss: 0.00154..
# Epoch: 295/400..  Training Loss: 0.00289..  Test Loss: 0.00141..
# 1 Epoch time cost 9.585
# Epoch: 296/400..  Training Loss: 0.00282..  Test Loss: 0.00123..
# 1 Epoch time cost 8.865
# Epoch: 297/400..  Training Loss: 0.00329..  Test Loss: 0.00154..
# 1 Epoch time cost 9.020
# Epoch: 298/400..  Training Loss: 0.00331..  Test Loss: 0.00151..
# Epoch: 298/400..  Training Loss: 0.00321..  Test Loss: 0.00145..
# 1 Epoch time cost 9.530
# Epoch: 299/400..  Training Loss: 0.00329..  Test Loss: 0.00207..
# 1 Epoch time cost 8.613
# Epoch: 300/400..  Training Loss: 0.00319..  Test Loss: 0.00140..
# Epoch: 300/400..  Training Loss: 0.00300..  Test Loss: 0.00157..
# 1 Epoch time cost 10.633
# 2018-05-06-22-18-57_keypoints_model_e299totale400_64_l_0.0002.pt
# Epoch: 301/400..  Training Loss: 0.00302..  Test Loss: 0.00182..
# 1 Epoch time cost 8.733
# Epoch: 302/400..  Training Loss: 0.00316..  Test Loss: 0.00259..
# 1 Epoch time cost 8.812
# Epoch: 303/400..  Training Loss: 0.00371..  Test Loss: 0.00163..
# Epoch: 303/400..  Training Loss: 0.00308..  Test Loss: 0.00134..
# 1 Epoch time cost 9.663
# Epoch: 304/400..  Training Loss: 0.00298..  Test Loss: 0.00136..
# 1 Epoch time cost 8.784
# Epoch: 305/400..  Training Loss: 0.00328..  Test Loss: 0.00205..
# Epoch: 305/400..  Training Loss: 0.00322..  Test Loss: 0.00191..
# 1 Epoch time cost 9.580
# Epoch: 306/400..  Training Loss: 0.00304..  Test Loss: 0.00130..
# 1 Epoch time cost 8.913
# Epoch: 307/400..  Training Loss: 0.00371..  Test Loss: 0.00186..
# 1 Epoch time cost 8.903
# Epoch: 308/400..  Training Loss: 0.00303..  Test Loss: 0.00148..
# Epoch: 308/400..  Training Loss: 0.00283..  Test Loss: 0.00145..
# 1 Epoch time cost 9.617
# Epoch: 309/400..  Training Loss: 0.00316..  Test Loss: 0.00156..
# 1 Epoch time cost 8.732
# Epoch: 310/400..  Training Loss: 0.00305..  Test Loss: 0.00130..
# Epoch: 310/400..  Training Loss: 0.00279..  Test Loss: 0.00135..
# 1 Epoch time cost 9.358
# Epoch: 311/400..  Training Loss: 0.00296..  Test Loss: 0.00130..
# 1 Epoch time cost 8.972
# Epoch: 312/400..  Training Loss: 0.00310..  Test Loss: 0.00146..
# 1 Epoch time cost 8.941
# Epoch: 313/400..  Training Loss: 0.00370..  Test Loss: 0.00142..
# Epoch: 313/400..  Training Loss: 0.00305..  Test Loss: 0.00140..
# 1 Epoch time cost 9.606
# Epoch: 314/400..  Training Loss: 0.00274..  Test Loss: 0.00123..
# 1 Epoch time cost 8.890
# Epoch: 315/400..  Training Loss: 0.00274..  Test Loss: 0.00125..
# Epoch: 315/400..  Training Loss: 0.00295..  Test Loss: 0.00137..
# 1 Epoch time cost 9.744
# Epoch: 316/400..  Training Loss: 0.00289..  Test Loss: 0.00127..
# 1 Epoch time cost 8.703
# Epoch: 317/400..  Training Loss: 0.00327..  Test Loss: 0.00153..
# 1 Epoch time cost 9.184
# Epoch: 318/400..  Training Loss: 0.00292..  Test Loss: 0.00140..
# Epoch: 318/400..  Training Loss: 0.00307..  Test Loss: 0.00133..
# 1 Epoch time cost 10.008
# Epoch: 319/400..  Training Loss: 0.00351..  Test Loss: 0.00128..
# 1 Epoch time cost 8.728
# Epoch: 320/400..  Training Loss: 0.00295..  Test Loss: 0.00134..
# Epoch: 320/400..  Training Loss: 0.00420..  Test Loss: 0.00212..
# 1 Epoch time cost 9.626
# Epoch: 321/400..  Training Loss: 0.00374..  Test Loss: 0.00172..
# 1 Epoch time cost 8.749
# Epoch: 322/400..  Training Loss: 0.00313..  Test Loss: 0.00132..
# 1 Epoch time cost 8.975
# Epoch: 323/400..  Training Loss: 0.00286..  Test Loss: 0.00158..
# Epoch: 323/400..  Training Loss: 0.00275..  Test Loss: 0.00131..
# 1 Epoch time cost 9.474
# Epoch: 324/400..  Training Loss: 0.00286..  Test Loss: 0.00163..
# 1 Epoch time cost 8.579
# Epoch: 325/400..  Training Loss: 0.00299..  Test Loss: 0.00125..
# Epoch: 325/400..  Training Loss: 0.00293..  Test Loss: 0.00136..
# 1 Epoch time cost 9.434
# Epoch: 326/400..  Training Loss: 0.00287..  Test Loss: 0.00137..
# 1 Epoch time cost 8.834
# Epoch: 327/400..  Training Loss: 0.00297..  Test Loss: 0.00131..
# 1 Epoch time cost 8.737
# Epoch: 328/400..  Training Loss: 0.00297..  Test Loss: 0.00159..
# Epoch: 328/400..  Training Loss: 0.00303..  Test Loss: 0.00129..
# 1 Epoch time cost 10.260
# Epoch: 329/400..  Training Loss: 0.00282..  Test Loss: 0.00144..
# 1 Epoch time cost 9.300
# Epoch: 330/400..  Training Loss: 0.00321..  Test Loss: 0.00197..
# Epoch: 330/400..  Training Loss: 0.00298..  Test Loss: 0.00220..
# 1 Epoch time cost 10.102
# Epoch: 331/400..  Training Loss: 0.00280..  Test Loss: 0.00144..
# 1 Epoch time cost 9.040
# Epoch: 332/400..  Training Loss: 0.00324..  Test Loss: 0.00171..
# 1 Epoch time cost 9.006
# Epoch: 333/400..  Training Loss: 0.00287..  Test Loss: 0.00145..
# Epoch: 333/400..  Training Loss: 0.00318..  Test Loss: 0.00135..
# 1 Epoch time cost 9.847
# Epoch: 334/400..  Training Loss: 0.00297..  Test Loss: 0.00262..
# 1 Epoch time cost 9.021
# Epoch: 335/400..  Training Loss: 0.00289..  Test Loss: 0.00115..
# Epoch: 335/400..  Training Loss: 0.00279..  Test Loss: 0.00153..
# 1 Epoch time cost 9.891
# Epoch: 336/400..  Training Loss: 0.00295..  Test Loss: 0.00132..
# 1 Epoch time cost 8.981
# Epoch: 337/400..  Training Loss: 0.00267..  Test Loss: 0.00146..
# 1 Epoch time cost 8.949
# Epoch: 338/400..  Training Loss: 0.00283..  Test Loss: 0.00133..
# Epoch: 338/400..  Training Loss: 0.00294..  Test Loss: 0.00164..
# 1 Epoch time cost 9.808
# Epoch: 339/400..  Training Loss: 0.00304..  Test Loss: 0.00144..
# 1 Epoch time cost 8.971
# Epoch: 340/400..  Training Loss: 0.00347..  Test Loss: 0.00166..
# Epoch: 340/400..  Training Loss: 0.00315..  Test Loss: 0.00123..
# 1 Epoch time cost 9.822
# Epoch: 341/400..  Training Loss: 0.00287..  Test Loss: 0.00130..
# 1 Epoch time cost 9.021
# Epoch: 342/400..  Training Loss: 0.00269..  Test Loss: 0.00135..
# 1 Epoch time cost 9.000
# Epoch: 343/400..  Training Loss: 0.00283..  Test Loss: 0.00135..
# Epoch: 343/400..  Training Loss: 0.00305..  Test Loss: 0.00151..
# 1 Epoch time cost 9.817
# Epoch: 344/400..  Training Loss: 0.00277..  Test Loss: 0.00121..
# 1 Epoch time cost 9.031
# Epoch: 345/400..  Training Loss: 0.00288..  Test Loss: 0.00128..
# Epoch: 345/400..  Training Loss: 0.00297..  Test Loss: 0.00125..
# 1 Epoch time cost 9.843
# Epoch: 346/400..  Training Loss: 0.00301..  Test Loss: 0.00133..
# 1 Epoch time cost 9.003
# Epoch: 347/400..  Training Loss: 0.00293..  Test Loss: 0.00123..
# 1 Epoch time cost 9.131
# Epoch: 348/400..  Training Loss: 0.00267..  Test Loss: 0.00126..
# Epoch: 348/400..  Training Loss: 0.00276..  Test Loss: 0.00147..
# 1 Epoch time cost 9.890
# Epoch: 349/400..  Training Loss: 0.00321..  Test Loss: 0.00135..
# 1 Epoch time cost 8.996
# Epoch: 350/400..  Training Loss: 0.00269..  Test Loss: 0.00113..
# Epoch: 350/400..  Training Loss: 0.00283..  Test Loss: 0.00112..
# 1 Epoch time cost 9.863
# Epoch: 351/400..  Training Loss: 0.00290..  Test Loss: 0.00146..
# 1 Epoch time cost 9.036
# Epoch: 352/400..  Training Loss: 0.00310..  Test Loss: 0.00152..
# 1 Epoch time cost 9.047
# Epoch: 353/400..  Training Loss: 0.00273..  Test Loss: 0.00126..
# Epoch: 353/400..  Training Loss: 0.00285..  Test Loss: 0.00114..
# 1 Epoch time cost 9.912
# Epoch: 354/400..  Training Loss: 0.00302..  Test Loss: 0.00168..
# 1 Epoch time cost 8.991
# Epoch: 355/400..  Training Loss: 0.00278..  Test Loss: 0.00118..
# Epoch: 355/400..  Training Loss: 0.00269..  Test Loss: 0.00117..
# 1 Epoch time cost 9.830
# Epoch: 356/400..  Training Loss: 0.00311..  Test Loss: 0.00116..
# 1 Epoch time cost 8.996
# Epoch: 357/400..  Training Loss: 0.00322..  Test Loss: 0.00146..
# 1 Epoch time cost 9.236
# Epoch: 358/400..  Training Loss: 0.00280..  Test Loss: 0.00140..
# Epoch: 358/400..  Training Loss: 0.00285..  Test Loss: 0.00149..
# 1 Epoch time cost 9.899
# Epoch: 359/400..  Training Loss: 0.00283..  Test Loss: 0.00148..
# 1 Epoch time cost 8.894
# Epoch: 360/400..  Training Loss: 0.00285..  Test Loss: 0.00118..
# Epoch: 360/400..  Training Loss: 0.00293..  Test Loss: 0.00133..
# 1 Epoch time cost 9.457
# Epoch: 361/400..  Training Loss: 0.00284..  Test Loss: 0.00129..
# 1 Epoch time cost 8.753
# Epoch: 362/400..  Training Loss: 0.00298..  Test Loss: 0.00126..
# 1 Epoch time cost 8.879
# Epoch: 363/400..  Training Loss: 0.00303..  Test Loss: 0.00129..
# Epoch: 363/400..  Training Loss: 0.00300..  Test Loss: 0.00137..
# 1 Epoch time cost 9.500
# Epoch: 364/400..  Training Loss: 0.00293..  Test Loss: 0.00143..
# 1 Epoch time cost 8.685
# Epoch: 365/400..  Training Loss: 0.00283..  Test Loss: 0.00132..
# Epoch: 365/400..  Training Loss: 0.00341..  Test Loss: 0.00129..
# 1 Epoch time cost 10.092
# Epoch: 366/400..  Training Loss: 0.00306..  Test Loss: 0.00141..
# 1 Epoch time cost 9.255
# Epoch: 367/400..  Training Loss: 0.00308..  Test Loss: 0.00128..
# 1 Epoch time cost 8.800
# Epoch: 368/400..  Training Loss: 0.00318..  Test Loss: 0.00144..
# Epoch: 368/400..  Training Loss: 0.00348..  Test Loss: 0.00128..
# 1 Epoch time cost 9.653
# Epoch: 369/400..  Training Loss: 0.00274..  Test Loss: 0.00144..
# 1 Epoch time cost 9.083
# Epoch: 370/400..  Training Loss: 0.00274..  Test Loss: 0.00117..
# Epoch: 370/400..  Training Loss: 0.00310..  Test Loss: 0.00136..
# 1 Epoch time cost 10.077
# Epoch: 371/400..  Training Loss: 0.00295..  Test Loss: 0.00132..
# 1 Epoch time cost 8.854
# Epoch: 372/400..  Training Loss: 0.00308..  Test Loss: 0.00179..
# 1 Epoch time cost 8.966
# Epoch: 373/400..  Training Loss: 0.00275..  Test Loss: 0.00126..
# Epoch: 373/400..  Training Loss: 0.00272..  Test Loss: 0.00145..
# 1 Epoch time cost 10.037
# Epoch: 374/400..  Training Loss: 0.00270..  Test Loss: 0.00120..
# 1 Epoch time cost 9.153
# Epoch: 375/400..  Training Loss: 0.00351..  Test Loss: 0.00207..
# Epoch: 375/400..  Training Loss: 0.00309..  Test Loss: 0.00180..
# 1 Epoch time cost 9.947
# Epoch: 376/400..  Training Loss: 0.00297..  Test Loss: 0.00133..
# 1 Epoch time cost 9.199
# Epoch: 377/400..  Training Loss: 0.00296..  Test Loss: 0.00157..
# 1 Epoch time cost 9.121
# Epoch: 378/400..  Training Loss: 0.00270..  Test Loss: 0.00129..
# Epoch: 378/400..  Training Loss: 0.00267..  Test Loss: 0.00122..
# 1 Epoch time cost 10.035
# Epoch: 379/400..  Training Loss: 0.00275..  Test Loss: 0.00122..
# 1 Epoch time cost 9.288
# Epoch: 380/400..  Training Loss: 0.00265..  Test Loss: 0.00111..
# Epoch: 380/400..  Training Loss: 0.00272..  Test Loss: 0.00116..
# 1 Epoch time cost 10.030
# Epoch: 381/400..  Training Loss: 0.00273..  Test Loss: 0.00137..
# 1 Epoch time cost 9.200
# Epoch: 382/400..  Training Loss: 0.00264..  Test Loss: 0.00126..
# 1 Epoch time cost 9.294
# Epoch: 383/400..  Training Loss: 0.00288..  Test Loss: 0.00148..
# Epoch: 383/400..  Training Loss: 0.00290..  Test Loss: 0.00122..
# 1 Epoch time cost 10.144
# Epoch: 384/400..  Training Loss: 0.00284..  Test Loss: 0.00123..
# 1 Epoch time cost 9.204
# Epoch: 385/400..  Training Loss: 0.00312..  Test Loss: 0.00131..
# Epoch: 385/400..  Training Loss: 0.00288..  Test Loss: 0.00138..
# 1 Epoch time cost 10.050
# Epoch: 386/400..  Training Loss: 0.00294..  Test Loss: 0.00124..
# 1 Epoch time cost 9.324
# Epoch: 387/400..  Training Loss: 0.00267..  Test Loss: 0.00120..
# 1 Epoch time cost 9.221
# Epoch: 388/400..  Training Loss: 0.00284..  Test Loss: 0.00123..
# Epoch: 388/400..  Training Loss: 0.00302..  Test Loss: 0.00165..
# 1 Epoch time cost 10.046
# Epoch: 389/400..  Training Loss: 0.00272..  Test Loss: 0.00152..
# 1 Epoch time cost 9.201
# Epoch: 390/400..  Training Loss: 0.00274..  Test Loss: 0.00126..
# Epoch: 390/400..  Training Loss: 0.00271..  Test Loss: 0.00118..
# 1 Epoch time cost 10.029
# Epoch: 391/400..  Training Loss: 0.00317..  Test Loss: 0.00117..
# 1 Epoch time cost 9.245
# Epoch: 392/400..  Training Loss: 0.00301..  Test Loss: 0.00121..
# 1 Epoch time cost 9.092
# Epoch: 393/400..  Training Loss: 0.00311..  Test Loss: 0.00124..
# Epoch: 393/400..  Training Loss: 0.00289..  Test Loss: 0.00121..
# 1 Epoch time cost 10.109
# Epoch: 394/400..  Training Loss: 0.00276..  Test Loss: 0.00114..
# 1 Epoch time cost 9.255
# Epoch: 395/400..  Training Loss: 0.00262..  Test Loss: 0.00177..
# Epoch: 395/400..  Training Loss: 0.00284..  Test Loss: 0.00161..
# 1 Epoch time cost 9.779
# Epoch: 396/400..  Training Loss: 0.00274..  Test Loss: 0.00126..
# 1 Epoch time cost 8.843
# Epoch: 397/400..  Training Loss: 0.00271..  Test Loss: 0.00136..
# 1 Epoch time cost 8.878
# Epoch: 398/400..  Training Loss: 0.00286..  Test Loss: 0.00147..
# Epoch: 398/400..  Training Loss: 0.00290..  Test Loss: 0.00126..
# 1 Epoch time cost 9.441
# Epoch: 399/400..  Training Loss: 0.00313..  Test Loss: 0.00154..
# 1 Epoch time cost 8.724
# Epoch: 400/400..  Training Loss: 0.00294..  Test Loss: 0.00142..
# Epoch: 400/400..  Training Loss: 0.00301..  Test Loss: 0.00139..
# 1 Epoch time cost 9.508
# 2018-05-06-22-34-30_keypoints_model_e399totale400_64_l_0.0002.pt
# Finished Training
# Total time cost 3609.4770658016205
# Net(
#   (conv1): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1))
#   (conv1_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(32, 40, kernel_size=(5, 5), stride=(1, 1))
#   (conv2_bn): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(40, 64, kernel_size=(4, 4), stride=(1, 1))
#   (conv3_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#   (conv4_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4_drop): Dropout(p=0.3)
#   (fc1): Linear(in_features=15488, out_features=5000, bias=True)
#   (fc1_drop): Dropout(p=0.3)
#   (fc2): Linear(in_features=5000, out_features=136, bias=True)
# )

# %% [markdown]
# ## Test data
#
# See how your model performs on previously unseen, test data. We've already loaded and transformed this data, similar to the training data. Next, run your trained model on these images to see what kind of keypoints are produced. You should be able to see if your model is fitting each new face it sees, if the points are distributed randomly, or if the points have actually overfitted the training data and do not generalize.

# %%
# get a sample of test data again
test_images, test_outputs, gt_pts,feature_map = net_sample_output()

print(test_images.data.size())
print(test_outputs.data.size())
print(gt_pts.size())
# Out:
# torch.Size([10, 32, 110, 110])
# torch.Size([10, 1, 224, 224])
# torch.Size([10, 68, 2])
# torch.Size([10, 68, 2])

# %%
## TODO: visualize your test output
# you can use the same function as before, by un-commenting the line below:

visualize_output(test_images, test_outputs, gt_pts)

# %% [markdown]
# Once we have found a good model (or two), save model so we can load it and use it later!

# %%
print("Our model: \n\n", net, '\n')
print("The state dict keys: \n\n", net.state_dict().keys())
# Out:
# Our model:
#
#  Net(
#   (conv1): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1))
#   (conv1_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(32, 40, kernel_size=(5, 5), stride=(1, 1))
#   (conv2_bn): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(40, 64, kernel_size=(4, 4), stride=(1, 1))
#   (conv3_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#   (conv4_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4_drop): Dropout(p=0.3)
#   (fc1): Linear(in_features=15488, out_features=5000, bias=True)
#   (fc1_drop): Dropout(p=0.3)
#   (fc2): Linear(in_features=5000, out_features=136, bias=True)
# )
#
# The state dict keys:
#
#  odict_keys(['conv1.weight', 'conv1.bias', 'conv1_bn.weight', 'conv1_bn.bias', 'conv1_bn.running_mean', 'conv1_bn.running_var', 'conv2.weight', 'conv2.bias', 'conv2_bn.weight', 'conv2_bn.bias', 'conv2_bn.running_mean', 'conv2_bn.running_var', 'conv3.weight', 'conv3.bias', 'conv3_bn.weight', 'conv3_bn.bias', 'conv3_bn.running_mean', 'conv3_bn.running_var', 'conv4.weight', 'conv4.bias', 'conv4_bn.weight', 'conv4_bn.bias', 'conv4_bn.running_mean', 'conv4_bn.running_var', 'fc1.weight', 'fc1.bias', 'fc2.weight', 'fc2.bias'])

# %%
save_time = datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")
#print(save_time)
## change the name to something uniqe for each new model
model_dir = 'saved_models/'
model_name = save_time+'_keypoints_model_'+'e'+str(n_epochs)+'_'+str(train_batch_size)+'_l_'+str(learning_rate)+'.pt'
print(model_name)
# after training, save your model parameters in the dir 'saved_models'
torch.save(net.state_dict(), model_dir+model_name)
# Out:
# 2018-05-06-22-34-38_keypoints_model_e400_64_l_0.0002.pt

# %% [markdown]
# ## Feature Visualization
#
# Sometimes, neural networks are thought of as a black box, given some input, they learn to produce some output. CNN's are actually learning to recognize a variety of spatial patterns and you can visualize what each convolutional layer has been trained to recognize by looking at the weights that make up each convolutional kernel and applying those one at a time to a sample image. This technique is called feature visualization and it's useful for understanding the inner workings of a CNN.

# %% [markdown]
# In the cell below, you can see how to extract a single filter (by index) from your first convolutional layer. The filter should appear as a grayscale grid.

# %%
######################
# show conv1 
#######################
# Get the weights in the first conv layer, "conv1"
# if necessary, change this to reflect the name of your first conv layer
weights1 = net.conv1.weight.data

#w = weights1.numpy()
w = weights1.cpu().numpy()

filter_index = 0
print(w.shape)
print(w[filter_index][0])
print(w[filter_index][0].shape)

# display the filter weights
plt.imshow(w[filter_index][0], cmap='gray')
plt.show()


#show the filter
filters,_,fw,fh = w.shape

fig=plt.figure(figsize=(20, 8))
columns = 4
rows = 8
for i in range(0, columns*rows):
    fig.add_subplot(rows, columns, i+1)
    plt.imshow(w[i][0], cmap='gray')
    
print('First convolutional layer')
plt.show()
# Out:
# (32, 1, 5, 5)
# [[ 0.15111086  0.08087096 -0.03768282  0.20411427 -0.10067861]
#  [-0.1660805   0.0373752  -0.05516879 -0.02978055  0.24381864]
#  [ 0.08405674 -0.1307997   0.05971779  0.18724871  0.03229902]
#  [-0.18849264  0.04647268 -0.12074747 -0.07495638 -0.02180624]
#  [ 0.09214205 -0.11340753 -0.15077129 -0.15297732  0.00961801]]
# (5, 5)
# First convolutional layer

# %% [markdown]
# ## Feature maps
#
# Each CNN has at least one convolutional layer that is composed of stacked filters (also known as convolutional kernels). As a CNN trains, it learns what weights to include in it's convolutional kernels and when these kernels are applied to some input image, they produce a set of **feature maps**. So, feature maps are just sets of filtered images; they are the images produced by applying a convolutional kernel to an input image. These maps show us the features that the different layers of the neural network learn to extract. For example, you might imagine a convolutional kernel that detects the vertical edges of a face or another one that detects the corners of eyes. You can see what kind of features each of these kernels detects by applying them to an image. One such example is shown below; from the way it brings out the lines in an the image, you might characterize this as an edge detection filter.
#
# <img src='images/feature_map_ex.png' width=50% height=50%/>
#
#
# Next, choose a test image and filter it with one of the convolutional kernels in your trained CNN; look at the filtered output to get an idea what that particular kernel detects.
#
# ### Filter an image to see the effect of a convolutional kernel
# ---

# %%
###############
# feature map conv1
###############
def show_feature(layer,rows,culs):
    
    ori_img = test_images[0].data.cpu().numpy()
    print(ori_img.shape)
    plt.imshow(ori_img[0],cmap='gray')
    plt.show()


    fmap = feature_map[layer].data.cpu().numpy()
    print(fmap.shape)

    num_img = fmap.shape[0]
    num_feature = fmap.shape[1]


    #for i in range(num_img):
    for i in range(1):
        fig=plt.figure(figsize=(50, 50))

        for j in range(num_feature):

            img = fmap[i][j]
            #print(img.shape)
            #print(roi.shape)
            #plt.figure()
            fig.add_subplot(rows, culs, j+1)

            plt.imshow(img,cmap='gray')
        plt.show()

# %%
#conv1
show_feature(0,5,7)
# Out:
# (1, 224, 224)
# (10, 32, 110, 110)

# %%
#conv2
show_feature(1,8,5)
# Out:
# (1, 224, 224)
# (10, 40, 53, 53)

# %%
#conv3
show_feature(2,8,8)
# Out:
# (1, 224, 224)
# (10, 64, 25, 25)

# %%
#conv4
show_feature(3,12,12)
# Out:
# (1, 224, 224)
# (10, 128, 11, 11)

# %% [markdown]
# ---
# ## Moving on!
#
# Now that you've defined and trained your model (and saved the best model), you are ready to move on to the last notebook, which combines a face detector with your saved model to create a facial keypoint detection system that can predict the keypoints on *any* face in an image!
